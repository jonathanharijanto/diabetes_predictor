# %%
import data_loader
import numpy as np
import pandas as pd

the_data = data_loader.load_dataset("dataset_diabetes/diabetes_data_preprocessed.csv")
#the_data = data_loader.load_dataset("dataset_diabetes/diabetes_data_test.csv")
outputs = ["1. Train Features:", "2. Train Labels:", "3. Valid Features:", "4. Valid Labels:", "5. Test Features:", "6. Test Labels:", "7. Label Dict:"]

for i in range(len(the_data)):
    print("\n" + outputs[i] + " --> len: " + str(len(the_data[i])) + "\n\n" + str(the_data[i]))
# Out:
# 1. Train Features: --> len: 76324
#
# [[97624 390825332 141470879 ... 1 0 -1.571488455]
#  [56387 161963778 101129301 ... 0 1 -0.243678438]
#  [94187 344965034 66855114 ... 0 1 1.08413158]
#  ...
#  [69027 195640206 115032240 ... 0 1 1.08413158]
#  [23061 78982944 87972786 ... 1 0 -1.571488455]
#  [28449 93241704 24712722 ... 0 1 -1.571488455]]
#
# 2. Train Labels: --> len: 76324
#
# [2 2 2 ... 2 1 2]
#
# 3. Valid Features: --> len: 8480
#
# [[75818 228078894 91578645 ... 1 0 -1.571488455]
#  [95778 366171320 71848674 ... 0 1 -1.571488455]
#  [34657 108243084 41603355 ... 0 1 1.08413158]
#  ...
#  [45596 140888442 87439923 ... 0 1 -0.243678438]
#  [84977 268687320 100677726 ... 0 1 1.08413158]
#  [26036 86188248 99117963 ... 0 1 -1.571488455]]
#
# 4. Valid Labels: --> len: 8480
#
# [2 2 2 ... 1 1 1]
#
# 5. Test Features: --> len: 9421
#
# [[1478 10034472 25507845 ... 0 1 1.08413158]
#  [6040 30549150 5444316 ... 1 0 -1.571488455]
#  [101490 440170274 141328517 ... 0 1 1.08413158]
#  ...
#  [21235 74123616 2277909 ... 0 1 1.08413158]
#  [52678 155541972 3843594 ... 0 1 1.08413158]
#  [10548 44602692 21341700 ... 1 0 1.08413158]]
#
# 6. Test Labels: --> len: 9421
#
# [2 2 2 ... 1 1 1]
#
# 7. Label Dict: --> len: 3
#
# {'<30': 0, '>30': 1, 'no': 2}

# %%
df = pd.read_csv("dataset_diabetes/diabetes_data_preprocessed.csv")

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 63 columns):
# Unnamed: 0                    101766 non-null int64
# encounter_id                  101766 non-null int64
# patient_nbr                   101766 non-null int64
# age                           101766 non-null int64
# time_in_hospital              101766 non-null int64
# num_medications               101766 non-null int64
# number_outpatient             101766 non-null float64
# number_emergency              101766 non-null float64
# number_inpatient              101766 non-null float64
# diag_1                        101766 non-null int64
# diag_2                        101766 non-null int64
# diag_3                        101766 non-null int64
# number_diagnoses              101766 non-null int64
# max_glu_serum                 101766 non-null int64
# metformin                     101766 non-null int64
# repaglinide                   101766 non-null int64
# nateglinide                   101766 non-null int64
# chlorpropamide                101766 non-null int64
# glimepiride                   101766 non-null int64
# acetohexamide                 101766 non-null int64
# glipizide                     101766 non-null int64
# glyburide                     101766 non-null int64
# tolbutamide                   101766 non-null int64
# pioglitazone                  101766 non-null int64
# rosiglitazone                 101766 non-null int64
# acarbose                      101766 non-null int64
# miglitol                      101766 non-null int64
# troglitazone                  101766 non-null int64
# tolazamide                    101766 non-null int64
# insulin                       101766 non-null int64
# glyburide-metformin           101766 non-null int64
# glipizide-metformin           101766 non-null int64
# glimepiride-pioglitazone      101766 non-null int64
# metformin-rosiglitazone       101766 non-null int64
# metformin-pioglitazone        101766 non-null int64
# change                        101766 non-null int64
# race_AfricanAmerican          101766 non-null int64
# race_Asian                    101766 non-null int64
# race_Caucasian                101766 non-null int64
# race_Hispanic                 101766 non-null int64
# race_Other                    101766 non-null int64
# gender_Female                 101766 non-null int64
# gender_Male                   101766 non-null int64
# A1Cresult_>7                  101766 non-null int64
# A1Cresult_>8                  101766 non-null int64
# A1Cresult_None                101766 non-null int64
# A1Cresult_Norm                101766 non-null int64
# admission_type_id_0           101766 non-null int64
# admission_type_id_1           101766 non-null int64
# admission_type_id_3           101766 non-null int64
# discharge_disposition_id_0    101766 non-null int64
# discharge_disposition_id_1    101766 non-null int64
# discharge_disposition_id_2    101766 non-null int64
# discharge_disposition_id_3    101766 non-null int64
# discharge_disposition_id_4    101766 non-null int64
# admission_source_id_0         101766 non-null int64
# admission_source_id_1         101766 non-null int64
# admission_source_id_2         101766 non-null int64
# admission_source_id_3         101766 non-null int64
# diabetesMed_No                101766 non-null int64
# diabetesMed_Yes               101766 non-null int64
# num_total_procedures          101766 non-null int64
# readmitted                    101766 non-null object
# dtypes: float64(3), int64(59), object(1)
# memory usage: 48.9+ MB
# None

# %%
X_train = the_data[0]
Y_train = the_data[1]

X_val = the_data[2]
Y_val = the_data[3]

X_test = the_data[4]
Y_test = the_data[5]

# %%
# # DECISION TREE

# from sklearn.model_selection import cross_val_score
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score

# the_results = []

# for i in range(1,101):
#     temp_results = [] 
#     for j in range(2,52):
#         dte = DecisionTreeClassifier(max_depth=i, min_samples_split=j)
#         dte.fit(X_train, Y_train)
#         Y_val_predict = dte.predict(X_val)
#         temp_results.append("{0:.2f}".format(accuracy_score(Y_val, Y_val_predict)))
#     the_results.append(temp_results)

# print(the_results)

# scores = cross_val_score(dte, X_train, Y_train, cv=10)
# print("Cross Validation score: {:.2%}".format(np.mean(scores)))

# %%
# RANDOM FOREST
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from pprint import pprint

forest = RandomForestClassifier(n_estimators = 100, max_depth=30, criterion = "gini")
# pprint(forest.get_params())
# forest = RandomForestClassifier()
# score = cross_val_score(forest, X_train, Y_train, cv=10)
# print(score)
forest.fit(X_train, Y_train)
Y_val_predict = forest.predict(X_val)
print(accuracy_score(Y_val, Y_val_predict))
# Out:
# 0.5976415094339622

# %%
import matplotlib.pyplot as plt
import pandas as pd

feature_imports = forest.feature_importances_
most_imp_features = pd.DataFrame(feature_imports)
print(most_imp_features)
# Out:
#                0
# 0   1.060266e-01
# 1   1.065063e-01
# 2   1.151473e-01
# 3   5.295040e-02
# 4   1.582956e-02
# 5   2.629637e-02
# 6   1.995755e-02
# 7   1.618042e-02
# 8   4.758451e-02
# 9   6.202645e-02
# 10  6.184484e-02
# 11  6.179233e-02
# 12  1.361986e-02
# 13  4.721666e-03
# 14  1.224059e-02
# 15  3.049843e-03
# 16  1.686629e-03
# 17  2.447896e-04
# 18  6.893031e-03
# 19  1.218919e-05
# 20  1.140375e-02
# 21  1.007376e-02
# 22  3.635201e-05
# 23  8.472428e-03
# 24  7.935653e-03
# 25  8.198807e-04
# 26  9.342796e-05
# 27  6.098708e-06
# 28  1.174266e-04
# 29  1.307831e-02
# ..           ...
# 32  0.000000e+00
# 33  9.411697e-07
# 34  1.010530e-06
# 35  1.468087e-02
# 36  1.094218e-02
# 37  1.329419e-03
# 38  1.212428e-02
# 39  3.174304e-03
# 40  4.313457e-03
# 41  1.485911e-02
# 42  1.471215e-02
# 43  5.052289e-03
# 44  7.088754e-03
# 45  1.042664e-02
# 46  5.662869e-03
# 47  5.532815e-03
# 48  9.660804e-03
# 49  8.206898e-03
# 50  1.097873e-02
# 51  9.171416e-03
# 52  8.016315e-03
# 53  2.508104e-03
# 54  3.321604e-04
# 55  3.093551e-03
# 56  5.109546e-03
# 57  4.626625e-03
# 58  7.648823e-06
# 59  5.440460e-03
# 60  5.313320e-03
# 61  2.933107e-02
#
# [62 rows x 1 columns]

# %%
feature_set_2_no_int = ['age', 'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'service_utilization_log1p', 
                 'number_diagnoses', 'nummed', 'race_AfricanAmerican', 'race_Asian', 
                 'race_Caucasian', 'race_Hispanic', 'race_Other', 'gender_1', 
                 'admission_type_id_3', 'admission_type_id_4', 'admission_type_id_5', 
                 'discharge_disposition_id_2', 'discharge_disposition_id_7', 
                 'discharge_disposition_id_10', 'discharge_disposition_id_18', 
                 'admission_source_id_4', 'admission_source_id_7', 'admission_source_id_8', 
                 'admission_source_id_9', 'admission_source_id_11', 'numchange', 
                 'A1Cresult_0', 'A1Cresult_1',
                 'level1_diag1_1.0',
                 'level1_diag1_2.0',
                 'level1_diag1_3.0',
                 'level1_diag1_4.0',
                 'level1_diag1_5.0',
                 'level1_diag1_6.0',
                 'level1_diag1_7.0',
                 'level1_diag1_8.0']
print(len(feature_set_2_no_int))
# Out:
# 36
