# %%
import data_loader
import numpy as np

the_data = data_loader.load_dataset("dataset_diabetes/diabetes_data_preprocessed.csv")
#the_data = data_loader.load_dataset("dataset_diabetes/diabetes_data_test.csv")
outputs = ["1. Train Features:", "2. Train Labels:", "3. Valid Features:", "4. Valid Labels:", "5. Test Features:", "6. Test Labels:", "7. Label Dict:"]

for i in range(len(the_data)):
    print("\n" + outputs[i] + " --> len: " + str(len(the_data[i])) + "\n\n" + str(the_data[i]))
# Out:
# 1. Train Features: --> len: 82433
#
# [[19983 70810734 98556642 ... 0 0 2]
#  [21242 74137860 2551572 ... 0 1 2]
#  [10887 45611196 23831505 ... 0 0 0]
#  ...
#  [100354 424891262 60570423 ... 0 1 1]
#  [89543 289501884 91563588 ... 0 1 2]
#  [9176 40327086 19095822 ... 1 1 1]]
#
# 2. Train Labels: --> len: 82433
#
# [2 2 2 ... 0 2 1]
#
# 3. Valid Features: --> len: 9158
#
# [[101247 436765574 85406454 ... 0 1 0]
#  [2348 15446892 79963830 ... 0 1 1]
#  [11505 47518116 2912436 ... 0 1 1]
#  ...
#  [89452 289020042 38882943 ... 0 1 0]
#  [101385 438529178 88785891 ... 0 0 0]
#  [23280 79571748 2670120 ... 1 1 1]]
#
# 4. Valid Labels: --> len: 9158
#
# [2 2 2 ... 0 0 0]
#
# 5. Test Features: --> len: 10175
#
# [[51502 153548118 100573605 ... 0 1 1]
#  [8046 37023612 598338 ... 1 1 2]
#  [50255 151121442 51819696 ... 0 1 0]
#  ...
#  [85073 269113332 85038084 ... 0 0 2]
#  [8332 37870290 1281573 ... 0 0 2]
#  [40701 126311478 23265909 ... 1 1 1]]
#
# 6. Test Labels: --> len: 10175
#
# [2 2 2 ... 0 0 0]
#
# 7. Label Dict: --> len: 3
#
# {'<30': 0, '>30': 1, 'no': 2}

# %%
X_train = the_data[0]
Y_train = the_data[1]

X_val = the_data[2]
Y_val = the_data[3]

X_test = the_data[4]
Y_test = the_data[5]

# %%
# DECISION TREE

from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score

the_results = []

for i in range(1,101):
    temp_results = [] 
    for j in range(2,52):
        dte = DecisionTreeClassifier(max_depth=i, min_samples_split=j)
        dte.fit(X_train, Y_train)
        Y_val_predict = dte.predict(X_val)
        temp_results.append("{0:.2f}".format(accuracy_score(Y_val, Y_val_predict)))
    the_results.append(temp_results)

print(the_results)

# scores = cross_val_score(dte, X_train, Y_train, cv=10)
# print("Cross Validation score: {:.2%}".format(np.mean(scores)))
# Out:
# [['0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56'], ['0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56', '0.56'], ['0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57'], ['0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57', '0.57'], ['0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58'], ['0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58', '0.58'], ['0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59'], ['0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59'], ['0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59'], ['0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.59', '0.5 ...

# %%
print(X_train.shape)
print(X_val.shape)

X_train = np.array(X_train)[:,3:]

X_val = np.array(X_val)[:,3:]

print(X_train.shape)
print(X_val.shape)
# Out:
# (82433, 44)
# (9158, 44)
# (82433, 41)
# (9158, 41)

# %%
# RANDOM FOREST
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from pprint import pprint

forest = RandomForestClassifier(n_estimators = 30, max_depth=15, criterion = "gini")
# pprint(forest.get_params())
# forest = RandomForestClassifier()
# score = cross_val_score(forest, X_train, Y_train, cv=10)
# print(score)
forest.fit(X_train, Y_train)
Y_val_predict = forest.predict(X_val)
print(accuracy_score(Y_val, Y_val_predict))
# Out:
# 0.5828783577200262

# %%
import matplotlib.pyplot as plt
import pandas as pd

feature_imports = forest.feature_importances_
most_imp_features = pd.DataFrame(feature_imports)
print(most_imp_features)
# Out:
#            0
# 0   0.130113
# 1   0.128476
# 2   0.021382
# 3   0.013597
# 4   0.046081
# 5   0.020885
# 6   0.066845
# 7   0.019052
# 8   0.012332
# 9   0.023855
# 10  0.034200
# 11  0.038380
# 12  0.128355
# 13  0.048099
# 14  0.047994
# 15  0.047891
# 16  0.020579
# 17  0.007018
# 18  0.012968
# 19  0.012938
# 20  0.003710
# 21  0.001902
# 22  0.000303
# 23  0.007007
# 24  0.000003
# 25  0.011666
# 26  0.009994
# 27  0.000054
# 28  0.008116
# 29  0.007087
# 30  0.001320
# 31  0.000113
# 32  0.000010
# 33  0.000179
# 34  0.023887
# 35  0.001753
# 36  0.000034
# 37  0.000000
# 38  0.000000
# 39  0.000000
# 40  0.010077
# 41  0.010627
# 42  0.021116
