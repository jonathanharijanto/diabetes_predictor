# %%
import data_loader

the_data = data_loader.load_dataset("dataset_diabetes/diabetic_data.csv")
print(the_data)

outputs = ["1. Train Features:", "2. Train Labels:", "3. Valid Features:", "4. Valid Labels:", "5. Test Features:", "6. Test Labels:", "7. Label Dict:"]

for i in range(len(the_data)):
    print("\n" + outputs[i] + " --> len: " + str(len(the_data[i])) + "\n\n" + str(the_data[i]))
# Out:
# (array([[341939006, 172536350, 'Caucasian', ..., 'No', 'No', 'Yes'],
#        [214053288, 85813002, 'Caucasian', ..., 'No', 'Ch', 'Yes'],
#        [319555778, 104996754, 'Caucasian', ..., 'No', 'Ch', 'Yes'],
#        ...,
#        [259948584, 40993047, 'Caucasian', ..., 'No', 'Ch', 'Yes'],
#        [159800298, 25293915, 'Caucasian', ..., 'No', 'Ch', 'Yes'],
#        [261241218, 65316006, 'AfricanAmerican', ..., 'No', 'No', 'No']],
#       dtype=object), array([1, 2, 1, ..., 1, 1, 1]), array([[436765574, 85406454, 'Caucasian', ..., 'No', 'No', 'Yes'],
#        [15446892, 79963830, 'AfricanAmerican', ..., 'No', 'No', 'Yes'],
#        [47518116, 2912436, 'Caucasian', ..., 'No', 'No', 'Yes'],
#        ...,
#        [289020042, 38882943, 'Caucasian', ..., 'No', 'No', 'Yes'],
#        [438529178, 88785891, 'Caucasian', ..., 'No', 'No', 'No'],
#        [79571748, 2670120, 'Caucasian', ..., 'No', 'Ch', 'Yes']],
#       dtype=object), array([1, 1, 1, ..., 0, 0, 0]), array([[153548118, 100573605, 'Caucasian', ..., 'No', 'No', 'Yes'],
#        [37023612, 598338, 'Caucasian', ..., 'No', 'Ch', 'Yes'],
#        [151121442, 51819696, 'Caucasian', ..., 'No', 'No', 'Yes'],
#        ...,
#        [269113332, 85038084, 'Caucasian', ..., 'No', 'No', 'No'],
#        [37870290, 1281573, 'Caucasian', ..., 'No', 'No', 'No'],
#        [126311478, 23265909, 'AfricanAmerican', ..., 'No', 'Ch', 'Yes']],
#       dtype=object), array([1, 1, 1, ..., 0, 0, 0]), {'<30': 0, 'no': 1, '>30': 2})
#
# 1. Train Features: --> len: 82433
#
# [[341939006 172536350 'Caucasian' ... 'No' 'No' 'Yes']
#  [214053288 85813002 'Caucasian' ... 'No' 'Ch' 'Yes']
#  [319555778 104996754 'Caucasian' ... 'No' 'Ch' 'Yes']
#  ...
#  [259948584 40993047 'Caucasian' ... 'No' 'Ch' 'Yes']
#  [159800298 25293915 'Caucasian' ... 'No' 'Ch' 'Yes']
#  [261241218 65316006 'AfricanAmerican' ... 'No' 'No' 'No']]
#
# 2. Train Labels: --> len: 82433
#
# [1 2 1 ... 1 1 1]
#
# 3. Valid Features: --> len: 9158
#
# [[436765574 85406454 'Caucasian' ... 'No' 'No' 'Yes']
#  [15446892 79963830 'AfricanAmerican' ... 'No' 'No' 'Yes']
#  [47518116 2912436 'Caucasian' ... 'No' 'No' 'Yes']
#  ...
#  [289020042 38882943 'Caucasian' ... 'No' 'No' 'Yes']
#  [438529178 88785891 'Caucasian' ... 'No' 'No' 'No']
#  [79571748 2670120 'Caucasian' ... 'No' 'Ch' 'Yes']]
#
# 4. Valid Labels: --> len: 9158
#
# [1 1 1 ... 0 0 0]
#
# 5. Test Features: --> len: 10175
#
# [[153548118 100573605 'Caucasian' ... 'No' 'No' 'Yes']
#  [37023612 598338 'Caucasian' ... 'No' 'Ch' 'Yes']
#  [151121442 51819696 'Caucasian' ... 'No' 'No' 'Yes']
#  ...
#  [269113332 85038084 'Caucasian' ... 'No' 'No' 'No']
#  [37870290 1281573 'Caucasian' ... 'No' 'No' 'No']
#  [126311478 23265909 'AfricanAmerican' ... 'No' 'Ch' 'Yes']]
#
# 6. Test Labels: --> len: 10175
#
# [1 1 1 ... 0 0 0]
#
# 7. Label Dict: --> len: 3
#
# {'<30': 0, 'no': 1, '>30': 2}

# %%
import pandas as pd

# df == dataframe 
df = pd.read_csv("dataset_diabetes/diabetic_data.csv")
print(df.shape)
# Out:
# (101766, 50)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
# encounter_id                101766 non-null int64
# patient_nbr                 101766 non-null int64
# race                        101766 non-null object
# gender                      101766 non-null object
# age                         101766 non-null object
# weight                      101766 non-null object
# admission_type_id           101766 non-null int64
# discharge_disposition_id    101766 non-null int64
# admission_source_id         101766 non-null int64
# time_in_hospital            101766 non-null int64
# payer_code                  101766 non-null object
# medical_specialty           101766 non-null object
# num_lab_procedures          101766 non-null int64
# num_procedures              101766 non-null int64
# num_medications             101766 non-null int64
# number_outpatient           101766 non-null int64
# number_emergency            101766 non-null int64
# number_inpatient            101766 non-null int64
# diag_1                      101766 non-null object
# diag_2                      101766 non-null object
# diag_3                      101766 non-null object
# number_diagnoses            101766 non-null int64
# max_glu_serum               101766 non-null object
# A1Cresult                   101766 non-null object
# metformin                   101766 non-null object
# repaglinide                 101766 non-null object
# nateglinide                 101766 non-null object
# chlorpropamide              101766 non-null object
# glimepiride                 101766 non-null object
# acetohexamide               101766 non-null object
# glipizide                   101766 non-null object
# glyburide                   101766 non-null object
# tolbutamide                 101766 non-null object
# pioglitazone                101766 non-null object
# rosiglitazone               101766 non-null object
# acarbose                    101766 non-null object
# miglitol                    101766 non-null object
# troglitazone                101766 non-null object
# tolazamide                  101766 non-null object
# examide                     101766 non-null object
# citoglipton                 101766 non-null object
# insulin                     101766 non-null object
# glyburide-metformin         101766 non-null object
# glipizide-metformin         101766 non-null object
# glimepiride-pioglitazone    101766 non-null object
# metformin-rosiglitazone     101766 non-null object
# metformin-pioglitazone      101766 non-null object
# change                      101766 non-null object
# diabetesMed                 101766 non-null object
# readmitted                  101766 non-null object
# dtypes: int64(13), object(37)
# memory usage: 38.8+ MB
# None

# %%
print(df.describe())
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# 50%                    1.000000             7.000000          4.000000
# 75%                    4.000000             7.000000          6.000000
# max                   28.000000            25.000000         14.000000
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# count       101766.000000   101766.000000    101766.000000      101766.000000
# mean            43.095641        1.339730        16.021844           0.369357
# std             19.674362        1.705807         8.127566           1.267265
# min              1.000000        0.000000         1.000000           0.000000
# 25%             31.000000        0.000000        10.000000           0.000000
# 50%             44.000000        1.000000        15.000000           0.000000
# 75%             57.000000        2.000000        20.000000           0.000000
# max            132.000000        6.000000        81.000000          42.000000
#
#        number_emergency  number_inpatient  number_diagnoses
# count     101766.000000     101766.000000     101766.000000
# mean           0.197836          0.635566          7.422607
# std            0.930472          1.262863          1.933600
# min            0.000000          0.000000          1.000000
# 25%            0.000000          0.000000          6.000000
# 50%            0.000000          0.000000          8.000000
# 75%            0.000000          1.000000          9.000000
# max           76.000000         21.000000         16.000000

# %%
age_dict = {}
for i in df['age']:
    if i in age_dict:
        age_dict[i] += 1
    else:
        age_dict[i] = 1

print('age\n', age_dict)
# Out:
# age
#  {'[0-10)': 161, '[10-20)': 691, '[20-30)': 1657, '[30-40)': 3775, '[40-50)': 9685, '[50-60)': 17256, '[60-70)': 22483, '[70-80)': 26068, '[80-90)': 17197, '[90-100)': 2793}

# %%
race_dict = {}
for i in df['race']:
    if i in race_dict:
        race_dict[i] += 1
    else:
        race_dict[i] = 1
print('race\n', race_dict)
# Out:
# race
#  {'Caucasian': 76099, 'AfricanAmerican': 19210, '?': 2273, 'Other': 1506, 'Asian': 641, 'Hispanic': 2037}

# %%
gender_dict = {}
for i in df['gender']:
    if i in gender_dict:
        gender_dict[i] += 1
    else:
        gender_dict[i] = 1
print('gender\n', gender_dict)
# Out:
# gender
#  {'Female': 54708, 'Male': 47055, 'Unknown/Invalid': 3}

# %%
a1c_dict = {}
for i in df['A1Cresult']:
    if i in a1c_dict:
        a1c_dict[i] += 1
    else:
        a1c_dict[i] = 1
print('A1Cresult\n', a1c_dict)
# Out:
# A1Cresult
#  {'None': 84748, '>7': 3812, '>8': 8216, 'Norm': 4990}

# %%
admission_type_id_dict = {}
for i in df['admission_type_id']:
    if i in admission_type_id_dict:
        admission_type_id_dict[i] += 1
    else:
        admission_type_id_dict[i] = 1
print('admission_type_id\n', admission_type_id_dict)
# Out:
# admission_type_id
#  {6: 5291, 1: 53990, 2: 18480, 3: 18869, 4: 10, 5: 4785, 8: 320, 7: 21}

# %%
discharge_disposition_id_dict = {}
for i in df['discharge_disposition_id']:
    if i in discharge_disposition_id_dict:
        discharge_disposition_id_dict[i] += 1
    else:
        discharge_disposition_id_dict[i] = 1
print('discharge_disposition_id\n', discharge_disposition_id_dict)
# Out:
# discharge_disposition_id
#  {25: 989, 1: 60234, 3: 13954, 6: 12902, 2: 2128, 5: 1184, 11: 1642, 7: 623, 10: 6, 4: 815, 14: 372, 18: 3691, 8: 108, 13: 399, 12: 3, 16: 11, 17: 14, 22: 1993, 23: 412, 9: 21, 20: 2, 15: 63, 24: 48, 28: 139, 19: 8, 27: 5}

# %%
admission_source_id_dict = {}
for i in df['admission_source_id']:
    if i in admission_source_id_dict:
        admission_source_id_dict[i] += 1
    else:
        admission_source_id_dict[i] = 1
print('admission_source_id\n', admission_source_id_dict)
# Out:
# admission_source_id
#  {1: 29565, 7: 57494, 2: 1104, 4: 3187, 5: 855, 6: 2264, 20: 161, 3: 187, 17: 6781, 8: 16, 9: 125, 14: 2, 10: 8, 22: 12, 11: 2, 25: 2, 13: 1}

# %%
max_glu_serum_dict = {}
for i in df['max_glu_serum']:
    if i in max_glu_serum_dict:
        max_glu_serum_dict[i] += 1
    else:
        max_glu_serum_dict[i] = 1
print('max_glu_serum\n', max_glu_serum_dict)
# Out:
# max_glu_serum
#  {'None': 96420, '>300': 1264, 'Norm': 2597, '>200': 1485}

# %%
print("List of Features that has '?' + the amount of '?':\n")

for col in df.columns:
    if df[col].dtype == object:
        missing_val = df[col][df[col] == '?'].count()
        if missing_val != 0:
            print(col,missing_val)

print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# List of Features that has '?' + the amount of '?':
#
# race 2273
# weight 98569
# payer_code 40256
# medical_specialty 49949
# diag_1 21
# diag_2 358
# diag_3 1423
# gender 3

# %%
drugs = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton', 'insulin', 'glyburide-metformin', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone']

for i in drugs:
    a_dict = {}
    for j in df[i]:
        if j in a_dict:
            a_dict[j] += 1
        else:
            a_dict[j] = 1
    print(i, a_dict)
# Out:
# metformin {'No': 81778, 'Steady': 18346, 'Up': 1067, 'Down': 575}
# repaglinide {'No': 100227, 'Up': 110, 'Steady': 1384, 'Down': 45}
# nateglinide {'No': 101063, 'Steady': 668, 'Down': 11, 'Up': 24}
# chlorpropamide {'No': 101680, 'Steady': 79, 'Down': 1, 'Up': 6}
# glimepiride {'No': 96575, 'Steady': 4670, 'Down': 194, 'Up': 327}
# acetohexamide {'No': 101765, 'Steady': 1}
# glipizide {'No': 89080, 'Steady': 11356, 'Up': 770, 'Down': 560}
# glyburide {'No': 91116, 'Steady': 9274, 'Up': 812, 'Down': 564}
# tolbutamide {'No': 101743, 'Steady': 23}
# pioglitazone {'No': 94438, 'Steady': 6976, 'Up': 234, 'Down': 118}
# rosiglitazone {'No': 95401, 'Steady': 6100, 'Up': 178, 'Down': 87}
# acarbose {'No': 101458, 'Steady': 295, 'Up': 10, 'Down': 3}
# miglitol {'No': 101728, 'Steady': 31, 'Down': 5, 'Up': 2}
# troglitazone {'No': 101763, 'Steady': 3}
# tolazamide {'No': 101727, 'Steady': 38, 'Up': 1}
# examide {'No': 101766}
# citoglipton {'No': 101766}
# insulin {'No': 47383, 'Up': 11316, 'Steady': 30849, 'Down': 12218}
# glyburide-metformin {'No': 101060, 'Steady': 692, 'Down': 6, 'Up': 8}
# glipizide-metformin {'No': 101753, 'Steady': 13}
# glimepiride-pioglitazone {'No': 101765, 'Steady': 1}
# metformin-rosiglitazone {'No': 101764, 'Steady': 2}
# metformin-pioglitazone {'No': 101765, 'Steady': 1}

# %%
import matplotlib.pyplot as plt

#print(df['race'])
df['race'].value_counts().sort_index().plot.bar()
plt.tight_layout()
plt.show()

# %%
df['age'].value_counts().sort_index().plot.bar()
plt.tight_layout()
plt.show()

# for col in df:
#     df[col].value_counts().sort_index().plot.bar()
# plt.tight_layout()
# plt.show()

# %%
features = ['race', 'gender', 'age', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
           'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 
            'number_emergency','number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum',
           'A1Cresult', 'change', 'diabetesMed', 'readmitted']

for feat in features:
    df[feat].value_counts().sort_index().plot.bar()
    plt.tight_layout()
    plt.show()
